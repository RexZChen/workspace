# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn import datasets, linear_model

data = pd.read_csv('./dataset/Hitters.csv')
# print(data)
Salary = ['Salary']
other_attr = ['AtBat', 'Hits', 'HmRun', 'Runs', 'RBI', 'Walks', 'Years', 'CAtBat', 'CHits', 'CHmRun', 'CWalks', 'PutOuts', 'Assists', 'Errors']
# print(data[Salary])
print(data[other_attr])
data = data.fillna(value=0)
print(data[Salary])
# Out:
#      AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  \
# 0      293    66      1    30   29     14      1     293     66       1
# 1      315    81      7    24   38     39     14    3449    835      69
# 2      479   130     18    66   72     76      3    1624    457      63
# 3      496   141     20    65   78     37     11    5628   1575     225
# 4      321    87     10    39   42     30      2     396    101      12
# 5      594   169      4    74   51     35     11    4408   1133      19
# 6      185    37      1    23    8     21      2     214     42       1
# 7      298    73      0    24   24      7      3     509    108       0
# 8      323    81      6    26   32      8      2     341     86       6
# 9      401    92     17    49   66     65     13    5206   1332     253
# 10     574   159     21   107   75     59     10    4631   1300      90
# 11     202    53      4    31   26     27      9    1876    467      15
# ...
